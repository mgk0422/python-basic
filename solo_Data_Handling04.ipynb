# %% [markdown]
# #### index객체
# -판다스의 index 객체는 DataFrame,Series의 레코드를 고유하게 식별하는 객체

# %%
import pandas as pd
import numpy as np

# %%
titanic_df=pd.read_csv('C://Users//mgk04.DESKTOP-8Q51H2D//Desktop//train.csv')
titanic_df.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %%
titanic_reset_df=titanic_df.reset_index(inplace=False) #reset_index -> 새롭게 인덱스를 연속 숫자형으로 할당하여 기존인덱스는 'index'라는 새로운 칼럼 명으로 추가된다.
titanic_reset_df
# Out:
#      index  PassengerId  Survived  Pclass  \
# 0        0            1         0       3
# 1        1            2         1       1
# 2        2            3         1       3
# 3        3            4         1       1
# 4        4            5         0       3
# 5        5            6         0       3
# 6        6            7         0       1
# 7        7            8         0       3
# 8        8            9         1       3
# 9        9           10         1       2
# 10      10           11         1       3
# 11      11           12         1       1
# 12      12           13         0       3
# 13      13           14         0       3
# 14      14           15         0       3
# 15      15           16         1       2
# 16      16           17         0       3
# 17      17           18         1       2
# 18      18           19         0       3
# 19      19           20         1       3
# 20      20           21         0       2
# ...

# %% [markdown]
# #### 데이터 셀렉션 및 필터링

# %% [markdown]
# - DataFrame의 []연산자

# %%
titanic_df['Pclass'].head(3)
# Out:
# 0    3
# 1    1
# 2    3
# Name: Pclass, dtype: int64

# %%
titanic_df[:2]
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked
# 0      0  A/5 21171   7.2500   NaN        S
# 1      0   PC 17599  71.2833   C85        C

# %%
# 불린 인덱싱 표현 [] 내의 불린 인덱싱 기능은 원하는 데이터를 편리하게 추출해주므로 자주 사용된다
titanic_df[titanic_df["Pclass"]==3]
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 2              3         1       3
# 4              5         0       3
# 5              6         0       3
# 7              8         0       3
# 8              9         1       3
# 10            11         1       3
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 16            17         0       3
# 18            19         0       3
# 19            20         1       3
# 22            23         1       3
# 24            25         0       3
# 25            26         1       3
# 26            27         0       3
# 28            29         1       3
# 29            30         0       3
# 32            33         1       3
# 36            37         1       3
# 37            38         0       3
# 38            39         0       3
# 39            40         1       3
# 40            41         0       3
# ...

# %%
titanic_df[0:2] # 라이싱 연산으로 데이터를 추출하는 방법은 좋은 방법이 아니다.
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked
# 0      0  A/5 21171   7.2500   NaN        S
# 1      0   PC 17599  71.2833   C85        C

# %% [markdown]
# #### DataFrame 연산자

# %%
data={'Name':['Chulmin','Eunkyung','Jinwoong','Soobeom'],
     'Year':[2011,2016,2015,2015],
     'GENDER':['Male','Female','Male','Male']
     }
data_df=pd.DataFrame(data,index=['one','two','three','four'])
data_df
# Out:
#            Name  Year  GENDER
# one     Chulmin  2011    Male
# two    Eunkyung  2016  Female
# three  Jinwoong  2015    Male
# four    Soobeom  2015    Male

# %%
data_df_reset=data_df.reset_index()
data_df_reset
# Out:
#    index      Name  Year  GENDER
# 0    one   Chulmin  2011    Male
# 1    two  Eunkyung  2016  Female
# 2  three  Jinwoong  2015    Male
# 3   four   Soobeom  2015    Male

# %% [markdown]
# - DataFrame iloc()연산자
# - iloc는 위치기반 인덱싱만 허용하기 때문에 행과 열 값으로 integer 또는 integer형의 슬라이싱, 팬시 리스트 값을 입려해야함

# %%
data_df.iloc[0,0]
# Out:
# 'Chulmin'

# %% [markdown]
# - DataFrame loc()연산자
# - loc는 명칭 기반으로 데이터를 추출합니다. 따라서 행 위치에는 DataFrame index 값을, 그리고 열 위치에는 컬럼명을 입력해줍니다.

# %%
data_df.loc['one','Name']
# Out:
# 'Chulmin'

# %%
data_df.loc['one':'two','Name']
# Out:
# one     Chulmin
# two    Eunkyung
# Name: Name, dtype: object

# %%
print(data_df_reset.loc[1:2,'Name'])
# Out:
# 1    Eunkyung
# 2    Jinwoong
# Name: Name, dtype: object

# %% [markdown]
# #### 불린 인덱싱

# %%
titanic_df.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %%
titanic_boolean=titanic_df[titanic_df['Age']>=60][['Name','Sex','Age']] #칼럼이 두개 이상이므로 [[]]사용
titanic_boolean
# Out:
#                                                  Name     Sex   Age
# 33                              Wheadon, Mr. Edward H    male  66.0
# 54                     Ostby, Mr. Engelhart Cornelius    male  65.0
# 96                          Goldschmidt, Mr. George B    male  71.0
# 116                              Connors, Mr. Patrick    male  70.5
# 170                         Van der hoef, Mr. Wyckoff    male  61.0
# 252                         Stead, Mr. William Thomas    male  62.0
# 275                 Andrews, Miss. Kornelia Theodosia  female  63.0
# 280                                  Duane, Mr. Frank    male  65.0
# 326                         Nysveen, Mr. Johan Hansen    male  61.0
# 366  Warren, Mrs. Frank Manley (Anna Sophia Atkinson)  female  60.0
# 438                                 Fortune, Mr. Mark    male  64.0
# 456                         Millet, Mr. Francis Davis    male  65.0
# 483                            Turkula, Mrs. (Hedwig)  female  63.0
# ...

# %%
titanic_df.loc[titanic_df['Age']>60,['Name','Age']].head(3) # 단, ['Name','Age']는 칼럼 위치에 놓여야 한다.
# Out:
#                               Name   Age
# 33           Wheadon, Mr. Edward H  66.0
# 54  Ostby, Mr. Engelhart Cornelius  65.0
# 96       Goldschmidt, Mr. George B  71.0

# %%
titanic_df[(titanic_df['Survived']==1) & (titanic_df['Age']>=60) & (titanic_df['Fare']>=70)]
# Out:
#      PassengerId  Survived  Pclass  \
# 275          276         1       1
# 366          367         1       1
# 587          588         1       1
# 829          830         1       1
#
#                                                  Name     Sex   Age  SibSp  \
# 275                 Andrews, Miss. Kornelia Theodosia  female  63.0      1
# 366  Warren, Mrs. Frank Manley (Anna Sophia Atkinson)  female  60.0      1
# 587                  Frolicher-Stehli, Mr. Maxmillian    male  60.0      1
# 829         Stone, Mrs. George Nelson (Martha Evelyn)  female  62.0      0
#
#      Parch  Ticket     Fare Cabin Embarked
# 275      0   13502  77.9583    D7        S
# 366      0  110813  75.2500   D37        C
# 587      1   13567  79.2000   B41        C
# 829      0  113572  80.0000   B28      NaN

# %% [markdown]
# ### 졍렬, Aggregation  함수, GroupBy 적용

# %% [markdown]
# - DataFrame, Series의 정렬 - sort_values()

# %% [markdown]
# - sort_values()의 주요 입력 파라미터는 by,ascending,inplace 입니다.
# - by로 특정 칼럼을 입력하면 해당 칼럼으로 정렬을 수행합니다.
# - ascending=True로 설정하면 오름차순으로 설정 (기본설정)
# - inplace=False로 설정하면 sort_values()를 호출한 DataFrame운 그대로 유지하며 정렬된 DataFrame을 결과로 반환한다(기본설정)

# %%
titanic_sorted=titanic_df.sort_values(by=['Name'])
titanic_sorted.head(3)
# Out:
#      PassengerId  Survived  Pclass                              Name     Sex  \
# 845          846         0       3               Abbing, Mr. Anthony    male
# 746          747         0       3       Abbott, Mr. Rossmore Edward    male
# 279          280         1       3  Abbott, Mrs. Stanton (Rosa Hunt)  female
#
#       Age  SibSp  Parch     Ticket   Fare Cabin Embarked
# 845  42.0      0      0  C.A. 5547   7.55   NaN        S
# 746  16.0      1      1  C.A. 2673  20.25   NaN        S
# 279  35.0      1      1  C.A. 2673  20.25   NaN        S

# %%
titanic_sorted=titanic_df.sort_values(by=['Pclass','Name'],ascending=False)
titanic_sorted.head(3)
# Out:
#      PassengerId  Survived  Pclass                             Name   Sex  \
# 868          869         0       3      van Melkebeke, Mr. Philemon  male
# 153          154         0       3  van Billiard, Mr. Austin Blyler  male
# 282          283         0       3        de Pelsmaeker, Mr. Alfons  male
#
#       Age  SibSp  Parch    Ticket  Fare Cabin Embarked
# 868   NaN      0      0    345777   9.5   NaN        S
# 153  40.5      0      2  A/5. 851  14.5   NaN        S
# 282  16.0      0      0    345778   9.5   NaN        S

# %% [markdown]
# ####  Aggregation 함수 적용

# %%
titanic_df.count()
# Out:
# PassengerId    891
# Survived       891
# Pclass         891
# Name           891
# Sex            891
# Age            714
# SibSp          891
# Parch          891
# Ticket         891
# Fare           891
# Cabin          204
# Embarked       889
# dtype: int64

# %% [markdown]
# - 특정 칼람에 aggregation 함수를 적용하기 위해서는 DataFrame에 대상 컬럼들만 추출해 aggregation을 적용하면 된다.

# %%
titanic_df[['Age','Fare']].mean()
# Out:
# Age     29.699118
# Fare    32.204208
# dtype: float64

# %% [markdown]
# #### groupby()적용

# %% [markdown]
# - DataFrame의 groupby() 사용시 입력 파라미터 by에 컬럼을 입력하면 대상 칼럼으로 group by된다.

# %%
titanic_groupby=titanic_df.groupby(by='Pclass')
titanic_groupby

# %%
titanic_groupby=titanic_df.groupby(by='Pclass').count()
titanic_groupby
# Out:
#         PassengerId  Survived  Name  Sex  Age  SibSp  Parch  Ticket  Fare  \
# Pclass
# 1               216       216   216  216  186    216    216     216   216
# 2               184       184   184  184  173    184    184     184   184
# 3               491       491   491  491  355    491    491     491   491
#
#         Cabin  Embarked
# Pclass
# 1         176       214
# 2          16       184
# 3          12       491

# %%
titanic_groupby=titanic_df.groupby(by='Pclass')[['PassengerId','Survived']].count()
titanic_groupby
# Out:
#         PassengerId  Survived
# Pclass
# 1               216       216
# 2               184       184
# 3               491       491

# %%
titanic_df.groupby(by='Pclass')['Age'].agg([max,min])
# Out:
#          max   min
# Pclass
# 1       80.0  0.92
# 2       70.0  0.67
# 3       74.0  0.42

# %%
agg_format={'Age':'max','SibSp':'sum','Fare':'mean'}
titanic_df.groupby('Pclass').agg(agg_format)
# Out:
#          Age  SibSp       Fare
# Pclass
# 1       80.0     90  84.154687
# 2       70.0     74  20.662183
# 3       74.0    302  13.675550

# %% [markdown]
# ### 결손 데이터 처리하기

# %% [markdown]
# - NaN 여부를 확인하는 API는 isna()이고, NaN값을 다른 값으로 대체하는 API는 fillna()입니다.

# %% [markdown]
# - isna()로 결손 데이터 여부 확인

# %%
titanic_df.isna().head(3)
# Out:
#    PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0        False     False   False  False  False  False  False  False   False
# 1        False     False   False  False  False  False  False  False   False
# 2        False     False   False  False  False  False  False  False   False
#
#     Fare  Cabin  Embarked
# 0  False   True     False
# 1  False  False     False
# 2  False   True     False

# %%
titanic_df.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
titanic_df['Canbin']=titanic_df['Cabin'].fillna('C000')
titanic_df.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked Canbin
# 0      0         A/5 21171   7.2500  C000        S   C000
# 1      0          PC 17599  71.2833   C85        C    C85
# 2      0  STON/O2. 3101282   7.9250  C000        S   C000

# %%
titanic_df['Age']=titanic_df['Age'].fillna(titanic_df['Age'].mean())
titanic_df['Embarked']=titanic_df['Embarked'].fillna('S')
titanic_df.isna().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# Canbin         0
# dtype: int64
