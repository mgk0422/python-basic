# %% [markdown]
# ### seaborn
# - 다양한 차트 지원

# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# lnline 실행시켜야 선이 그려짐

# %%
# 한글 폰트 문제 해결
import platform

from matplotlib import font_manager, rc
# plt.rcParams['axes.unicode_minus'] = False

if platform.system() == 'Darwin':
    rc('font', family='AppleGothic')
elif platform.system() == 'Windows':
    path = "c:/Windows/Fonts/malgun.ttf"
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)
else:
    print('Unknown system... sorry~~~~')

# %%
import matplotlib

matplotlib.rc('axes',unicode_minus=False) 

## 그래프 수치에 마이너스가 나올경우 오류 안나게 방지

# %%
import warnings
warnings.filterwarnings(action='ignore')  # warning이있을때 없애줌

# %% [markdown]
# - barplot() : 카테고리 값에 따른 실수 값의 평균과 편차를 표시하는 차트
# - 평균은 막대의 높이, 편차 에러바

# %%
iris=sns.load_dataset('iris')
titanic=sns.load_dataset('titanic')
tips=sns.load_dataset('tips')
flights=sns.load_dataset('flights')

# %%
# borplot
# 스타일 테마를 설정 5가지(darkgrid,whitegrid,dark,white,ticks)
sns.set_style('darkgrid')

# 그래프 객체를 생성하기 위한 피겨객체 얻어오기
fig=plt.figure(figsize=(15,5))

area01=fig.add_subplot(1,3,1)
area01.set_title('titanic survived -sex')
area02=fig.add_subplot(1,3,2)
area03=fig.add_subplot(1,3,3)

# 성별에 따른 생존률
sns.barplot(x='sex',y='survived',data=titanic,ax=area01)
# hue = 
sns.barplot(x='sex',y='survived',hue='class',data=titanic,ax=area02)
# dodge=False는 누적형식!!
sns.barplot(x='sex',y='survived',hue='class',dodge=False,data=titanic,ax=area03)
plt.show()

# %%
# tips barplot()
#  요일 별 전체 팁을 시각화
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
fig=plt.figure(figsize=(15,5))
sns.barplot(x='day',y='total_bill',data=tips)
plt.title("요일별 전체 팁")
plt.show()

# %% [markdown]
# - countplot() : 카테고리 값별로 데이터 빈도를 표시하는 차트 , x축의 빈도만 !! (y축 필요 ㄴㄴ 어차피 count니까!!)

# %%
# borplot
# 스타일 테마를 설정 5가지(darkgrid,whitegrid,dark,white,ticks)
sns.set_style('whitegrid')

# 그래프 객체를 생성하기 위한 피겨객체 얻어오기
fig=plt.figure(figsize=(15,5))

area01=fig.add_subplot(1,3,1)
area01.set_title('titanic class')
area02=fig.add_subplot(1,3,2)
area02.set_title('titanic class-who')
area03=fig.add_subplot(1,3,3)
area03.set_title('titanic class-who(stacked)')


# 성별에 따른 생존률
sns.countplot(x='class',data=titanic,ax=area01)
# hue =  그룹을 지어줌!
sns.countplot(x='class',hue='who',data=titanic,ax=area02,palette='Set3')
# dodge=False는 누적형식!!
sns.countplot(x='class',hue='who',dodge=False,data=titanic,ax=area03,palette='Set3')
plt.show()

# %%
# tips를 이용한 countplot
# 요일별로 팁을 준 빈도를 시각화 한다면?
sns.set_style('whitegrid')
fig=plt.figure(figsize=(15,5))
sns.countplot(x='day',data=tips,palette='Set3')
plt.title('요일별로 팁을 준 횟수')
plt.show()

# %% [markdown]
# - stripplot() : 스카터플롯처럼 모든 데이터를 점으로 시각화
# - jitter=True 설정하면 위치를 무작위로 바꿔서 겹치지 않게

# %%
fig=plt.figure(figsize=(15,5))
sns.stripplot(x='day',y='total_bill',data=tips,jitter=True)
plt.title("요일별 전체 팁")
plt.show()

# %%
sns.swarmplot(x='day',y='total_bill',data=tips)
plt.title("요일별 전체 팁")
plt.show()

# %%
# 타이타닉 데이터를 이용하여
# 서브플롯을 2개 영역으로 만들고
# class 별 나이의 분포를 확인하라(stripplot(),swarmplot())

titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
sns.set_style('whitegrid')
fig=plt.figure(figsize=(15,5))

area01=fig.add_subplot(1,2,1)
area01.set_title('stripplot')
area02=fig.add_subplot(1,2,2)
area02.set_title('swarmplot')

sns.stripplot(x='class',y='age',data=titanic,ax=area01,jitter=True)
sns.swarmplot(x='class',y='age',data=titanic,ax=area02)
plt.show()

# %% [markdown]
# - boxplot(), violinplot()

# %%
# 스타일 테마를 설정 5가지(darkgrid,whitegrid,dark,white,ticks)
sns.set_style('whitegrid')

# 그래프 객체를 생성하기 위한 피겨객체 얻어오기
fig=plt.figure(figsize=(15,5))

ax01=fig.add_subplot(2,2,1)
ax01.set_title('box')
ax02=fig.add_subplot(2,2,2)
ax02.set_title('box')
ax03=fig.add_subplot(2,2,3)
ax03.set_title('violin')
ax04=fig.add_subplot(2,2,4)
ax04.set_title('violin')

sns.boxplot(x='alive',y='age',data=titanic, ax=ax01)
sns.boxplot(x='alive',y='age',hue='sex',data=titanic, ax=ax02)
sns.violinplot(x='alive',y='age',data=titanic, ax=ax03)
sns.violinplot(x='alive',y='age',hue='sex',data=titanic, ax=ax04)

plt.show()

# %%
# 만약에 tips에서
# 요일별, 성별 전체 팁 stripplot()시각화
sns.stripplot(x='day', y='total_bill', hue='sex', data=tips,jitter=True )
plt.title('요일별 전체 팁')
plt.legend(loc='best')
plt.show()

# %%
# titanic
# 피벗테이블로 범주형 변수를 각각, 행,열로 재구분하여 정리
# 인덱스 성별, 열 클래스
table=titanic.pivot_table(index=['sex'],columns=['class'],aggfunc='size')
#table.head()
sns.heatmap(table,
           annot=True,fmt='d',
           linewidth=1)  #annot=True 수치 나오게 한다.fmt='d' 정수지정

# %%
# flights 연도, 월 별 승객수에 대한 heatmap
# pivot(index, columns, value) # 피벗은 하나의 벨류 !
# pivot_table(data, values, index, columns,aggfunc='mean') 
# x 연도 , y 월

# %%
flights.head()
# Out:
#    year     month  passengers
# 0  1949   January         112
# 1  1949  February         118
# 2  1949     March         132
# 3  1949     April         129
# 4  1949       May         121

# %%
heat_map=flights.pivot('month','year','passengers') # 피벗은 하나의 벨류 !
heat_map
# Out:
# year       1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  \
# month
# January     112   115   145   171   196   204   242   284   315   340   360
# February    118   126   150   180   196   188   233   277   301   318   342
# March       132   141   178   193   236   235   267   317   356   362   406
# April       129   135   163   181   235   227   269   313   348   348   396
# May         121   125   172   183   229   234   270   318   355   363   420
# June        135   149   178   218   243   264   315   374   422   435   472
# July        148   170   199   230   264   302   364   413   465   491   548
# August      148   170   199   242   272   293   347   405   467   505   559
# September   136   158   184   209   237   259   312   355   404   404   463
# October     119   133   162   191   211   229   274   306   347   359   407
# November    104   114   146   172   180   203   237   271   305   310   362
# December    118   140   166   194   201   229   278   306   336   337   405
#
# year       1960
# month
# January     417
# February    391
# March       419
# April       461
# May         472
# June        535
# July        622
# August      606
# September   508
# October     461
# November    390
# December    432

# %%
sns.heatmap(heat_map,
           annot=True,fmt='d',
           linewidth=1)  #annot=True 수치 나오게 한다.fmt='d' 정수지정
